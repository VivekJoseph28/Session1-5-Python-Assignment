# %% [markdown]
# ## Assignment 1 :- Python Session 1 Introduction to Basics

# %% [markdown]
# ### 1. Install Jupyter notebook and run the first program and share the screenshot of the output

# %%
name=input("Please Enter Your Name?")
print ("Hello",name,"to the World of Python")

# %% [markdown]
# ![Python%201.png](attachment:Python%201.png)

# %%
#-------------------------------------------------------------------------------#

# %%
from IPython.display import Image
Image(filename='C:/Users/vmjoseph/Desktop/Python Training and Codes/Acadgild/Assignments/Python 1.png'
      ,width=1000,height=100)

# %%
#----------------------------------------------------------------------------------------------#

# %% [markdown]
# ### 2. Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
#Initialising the list where the output need to be stored
kl=[]
# For loop using the range function and checking for the condition
for x in range(2000,3201):
    if (x%7==0) and (x%5!=0):
        kl.append(str(x))
# Displaying the output using ',' separator
print (','.join(kl))
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199

# %%
#-----------------------------------------------------------------------------------------------#

# %% [markdown]
# ### 3. Write a Python program to accept the users first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
#Input the first name
name1= input("First name ?")
#Input the second name
name2= input("Second name?")
print("Full name is",name1,name2)
print("Name in reverse",name2,'',name1)
# Out:
# First name ?Vivek
# Second name?Joseph
# Full name is Vivek  Joseph
# Name in reverse Joseph  Vivek

# %%
#-------------------------------------------------------------------------------------------------#

# %% [markdown]
# ### 4. Write a Python program to find the volume of a sphere with diameter 12 cm.
# Formula: V=4/3 * π * r 3

# %%
#Defining the function with argument diameter,perform the calculation and return the value 
def Sphere(d):
    pi=(22/7)
    V= (4/3)*pi*(d/2)**3
    return V
d=12.0
#d=input("The diameter of the sphere?")
print (Sphere(d))
# Out:
# 905.142857142857

# %%
#--------------------------------------------------------------------------------------------------#
